# %%
import matplotlib.pyplot as plt #import matplotlib package
import numpy as np 
x=[1,2,3,4,5,6,7,8,9]
y=[11,22,33,44,55,66,77,88,99]
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
y
# Out:
# [11, 22, 33, 44, 55, 66, 77, 88, 99]

# %%
plt.plot(x,y,'b') #'b' is for blue color of line
plt.xlabel('x array')# for x-axis
plt.ylabel('y axis title here') # for y-axis 
plt.title('string title here') #title of graph given
plt.show()

# %%
plt.subplot(2,2,1) #given args and kwargs
plt.plot(x,y,'v')
plt.subplot(2,1,2)#given args and kwargs
plt.plot(x,y,'r')
plt.subplot(1,2,2)#given args and kwargs
plt.plot(x,y,'b')

# %%
# create figure on empty canvas
fig=plt.figure()

# Add set of axes to figure
axes = fig.add_axes([0.1, .2, 0.5, 0.6]) # left, bottom, width, height (range 0 to 1)

# Plot on that set of axes
axes.plot(x,y,'b')
axes.set_xlabel('set x label')
axes.set_ylabel('set y label')
axes.set_title('set title')
# Out:
# Text(0.5,1,'set title')

# %%
plt.figure()

# %%
axes

# %%
# creates blank canvas
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.3,0.4,0.3])

#larger figure axes 1
axes1.plot(x, y, 'b')
axes1.set_xlabel('X_label_axes2')
axes1.set_ylabel('Y_label_axes2')
axes1.set_title('Axes 2 Title')

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5,1,'Axes 2 Title')
